# %% [markdown]
# # Python Moduels & Development Enviroments

# %% [markdown]
# ### Modules

# %%
from moduleExample import string

print(moduleExample.string)
# Out:
# This is a string from a module

# %%
import moduleExample

print(moduleExample.module_list)
# Out:
# [1, 2, 3, 4, 5, 6, 100]

# %%
print(moduleExample.fibonacci(10))
print(moduleExample.fibonacci(15))
# Out:
# 55
# 610

# %%
dir(moduleExample)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'fibonacci',
#  'module_list',
#  'string']

# %% [markdown]
# ### Webscraper using request and BeautifulSoup

# %%
import requests
from bs4 import BeautifulSoup

# %%
URL = 'https://www.jobindex.dk/jobsoegning/storkoebenhavn?q=software'
page = requests.get(URL)

page.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(page.content, 'html.parser')

results = soup.find(id='results')

job_elems = results.find_all('div', class_='PaidJob')
print(' ')
print(soup.prettify())
# Out:
#
# <!DOCTYPE html>
# <html lang="da-DK">
#  <head>
#   <title>
#    Ledige job - Software - Storkøbenhavn | Jobindex
#   </title>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta charset="utf-8"/>
#   <link href="/res/bootstrap-multiselect/dist/css/bootstrap-multiselect.css?h=6a6b68a249811e054fa8d759452816a9248c0748" rel="stylesheet"/>
#   <link href="/res/select2/dist/css/select2.min.css?h=a170ecdd58f00519741ed4b63abc064ef35db1a9" rel="stylesheet"/>
#   <link href="/res/bootstrap-datepicker/dist/css/bootstrap-datepicker3.standalone.min.css?h=f02cbfe4614ade97b3e5823be92702ae7bd445cd" rel="stylesheet"/>
#   <link href="/res/mapbox-gl/dist/mapbox-gl.css?h=0221a0dab467f93c80e8f5264c4f146e6d11496d" rel="stylesheet"/>
#   <link href="/res/font-awesome/css/font-awesome.css?h=ee906a8196d0fbd581c27a9d5615db4c250860f2" rel="stylesheet"/>
#   <link href="https://fonts.googleapis.com/css?family=Roboto:400,400i,500,500i,700,700i&amp;display=swap" rel="stylesheet"/>
# ...

# %%
for job_elem in job_elems:
    # Each job_elem is a new BeautifulSoup object.
    # You can use the same methods on it as you did before.
    title_elem = job_elem.find('b')
    location_elem = job_elem.find('p')
    description_elem = job_elem.find('i')
    furtherdescription_elem = job_elem.find('p')

    #Finding the link
    link = job_elem.findAll('a')
    link = str(link)
    link = link[link.find('data-click', link.find('/c'))+12:]
    print(link.find('rel', link.find('rel')))
    placement2 = link.find('href', link.find('href'))



    if title_elem is not None:
        print('Titel: '+title_elem.text.strip())
    if location_elem is not None:
        print('Lokation: '+location_elem.text.strip())
    if description_elem is not None:
        print('Beskrivelse: '+description_elem.text.strip())
    print('https://www.jobindex.dk' + link[:placement2 - 2])
    print('')
# Out:
# 71
# Titel: Produktspecialist
# Lokation: Scan-Med A/S
# https://www.jobindex.dk/c?t=h1044541&amp;ctx=w&amp;u=19058545
#
# 79
# Titel: Website Specialist
# Lokation: EPOS, Ballerup
# https://www.jobindex.dk/c?t=h1044580&amp;ctx=w&amp;u=20535310
#
# 66
# Titel: 3 PhD scholarships in Powering Internet of Things with Ambient Solutions
# Lokation: Danmarks Tekniske Universitet, Kongens Lyngby
# https://www.jobindex.dk/c?t=h1044557&amp;ctx=w&amp;u=13458128
#
# 66
# Titel: Business Consultant Graduate
# Lokation: KMD A/S, Ballerup
# https://www.jobindex.dk/c?t=h1044528&amp;ctx=w&amp;u=13590151
#
# 66
# Titel: Proposal Writer Graduate
# Lokation: KMD A/S, Ballerup
# https://www.jobindex.dk/c?t=h1044527&amp;ctx=w&amp;u=13590151
#
# 66
# Titel: Product/Release Manager Graduate
# Lokation: KMD A/S, Ballerup
# https://www.jobindex.dk/c?t=h1044525&amp;ctx=w&amp;u=13590151
#
# 66
# Titel: Software Engineer to world class R&D environment
# Lokation: Danmarks Tekniske Universitet, Kongens Lyngby
# ...

# %% [markdown]
# ##

# %% [markdown]
# # Development Enviroment

# %% [markdown]
# #### Jupyter

# %%
a = 'This is a scripting language '

# %%
b = 'no need to compile'

# %%
a
# Out:
# 'This is a scripting language '

# %%
b
# Out:
# 'no need to compile'

# %%
a+b
# Out:
# 'This is a scripting language no need to compile'

# %% [markdown]
# #### Docker

# %% [markdown]
# Building an image and gives the user a link:
#
# docker run --rm -p 8888:8888 -v ${PWD}:/home/jovyan/work jupyter/datascience-notebook

# %% [markdown]
# ##### Docker run
#
# docker run -it --rm -v ${PWD}:/docs python bash
#
# #### Flags in docker
#
# -i = interactive.
#
# -t = tty = identify the terminal.
#
# -it = open an interactive container instance.
#
#
# --rm = remove container when process exits.
#
# -v = volume = which folder should be mount to make them accessible inside the container.
